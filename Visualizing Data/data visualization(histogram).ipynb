# %%
import os
os.chdir("D:")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel("cars.xlsx")
plt.title("histogram")     #to write a title
plt.hist(data["KM"])
plt.show()

# %%
import os
os.chdir("D:")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("input.csv")
plt.title("histogram")     #to write a title
plt.hist(data["salary"],color="green",edgecolor="white",bins= 5)
plt.show()
