# %%
import os
os.chdir("D:")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel("cars.xlsx")
plt.title("scatter plot")     #to write a title
plt.scatter(data["Age"],data["Price"],c="red")
plt.show()

# %%
import os
os.chdir("D:")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("input.csv")
plt.title("scatter plot")     #to write a title
plt.scatter(data["name"],data["salary"],c="red")
plt.show()
