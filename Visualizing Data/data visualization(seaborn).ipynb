# %%
import os
os.chdir("D:")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_excel("cars.xlsx")
data.dropna(axis=0,inplace=True)
sns.regplot(x=data["Age"],y=data["Price"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
import os
os.chdir("D:")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_excel("cars.xlsx")
data.dropna(axis=0,inplace=True)
sns.regplot(x=data["Age"],y=data["Price"],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
import os
os.chdir("D:")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_excel("cars.xlsx")
data.dropna(axis=0,inplace=True)
sns.regplot(x=data["Age"],y=data["Price"],hue="FuelType",legend=True,palette="Set1")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f991d2f3df59> in <module>
#       7 data=pd.read_excel("cars.xlsx")
#       8 data.dropna(axis=0,inplace=True)
# ----> 9 sns.regplot(x=data["Age"],y=data["Price"],hue="FuelType",legend=True,palette="Set1")
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: regplot() got an unexpected keyword argument 'hue'
